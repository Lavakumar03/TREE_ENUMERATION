# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavakumar03/TREE_ENUMERATION/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO(r"/content/drive/MyDrive/New/best.pt")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-75273d3e42ac> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO(r"/content/drive/MyDrive/New/best.pt")
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
results = model(r"/content/drive/MyDrive/New/image3.jpg")
results
# Out:
# image 1/1 /content/drive/MyDrive/New/image3.jpg: 384x640 12 Trees, 116.1ms
# Speed: 1.9ms preprocess, 116.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Tree'}
#  orig_img: array([[[  0,  46,  25],
#          [  0,  53,  32],
#          [  3,  63,  39],
#          ...,
#          [  0,  20,   1],
#          [  3,  20,   6],
#          [  6,  20,   8]],
#
#         [[ 13,  70,  49],
#          [ 14,  73,  52],
#          [ 17,  75,  51],
#          ...,
#          [ 21,  46,  26],
#          [ 21,  40,  25],
#          [ 16,  30,  18]],
#
#         [[ 11,  67,  44],
#          [ 12,  70,  46],
#          [ 13,  69,  46],
#          ...,
#          [  0,  27,   7],
#          [  4,  25,  10],
#          [  9,  26,  13]],
#
#         ...,
#
#         [[  6,  79,  33],
#          [ 31, 104,  58],
# ...

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image
image=Image.fromarray(results[0].plot()[:,:,::-1])
plt.imshow(image)

# %%
results = model(r"/content/drive/MyDrive/New/single2.jpg")
results
# Out:
# image 1/1 /content/drive/MyDrive/New/single2.jpg: 480x640 1 Tree, 160.6ms
# Speed: 2.5ms preprocess, 160.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Tree'}
#  orig_img: array([[[143, 237, 173],
#          [ 80, 171, 108],
#          [ 69, 154,  92],
#          ...,
#          [ 15,  29,   0],
#          [ 28,  46,   7],
#          [ 37,  55,  14]],
#
#         [[118, 212, 148],
#          [ 84, 175, 112],
#          [ 85, 170, 108],
#          ...,
#          [ 44,  65,  27],
#          [ 36,  58,  16],
#          [ 41,  64,  20]],
#
#         [[106, 200, 136],
#          [ 79, 170, 107],
#          [ 86, 171, 109],
#          ...,
#          [ 22,  52,  11],
#          [ 20,  51,   6],
#          [ 16,  50,   3]],
#
#         ...,
#
#         [[ 54,  46,  39],
#          [ 54,  46,  39],
# ...

# %%
from PIL import Image
image=Image.fromarray(results[0].plot()[:,:,::-1])
plt.imshow(image)

# %%
results = model(r"/content/drive/MyDrive/New/image2.jpg")
results
# Out:
# image 1/1 /content/drive/MyDrive/New/image2.jpg: 384x640 32 Trees, 93.8ms
# Speed: 1.3ms preprocess, 93.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Tree'}
#  orig_img: array([[[  7,  21,  17],
#          [  6,  21,  17],
#          [  0,  11,   3],
#          ...,
#          [ 41, 125, 101],
#          [ 29, 115,  91],
#          [ 23, 108,  88]],
#
#         [[  9,  26,  17],
#          [  9,  28,  19],
#          [  0,  20,  10],
#          ...,
#          [  8,  90,  67],
#          [ 35, 119,  95],
#          [ 52, 137, 115]],
#
#         [[ 14,  35,  20],
#          [  9,  35,  19],
#          [  8,  37,  21],
#          ...,
#          [ 40, 120,  97],
#          [ 28, 110,  87],
#          [ 17, 102,  80]],
#
#         ...,
#
#         [[  0,  97,  47],
#          [  6, 103,  53],
# ...

# %%
from PIL import Image
image=Image.fromarray(results[0].plot()[:,:,::-1])
plt.imshow(image)
